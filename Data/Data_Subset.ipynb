# %% [markdown]
# # **NC vs GA Teen Births Rates Data Subset**

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("CountyHealthData_2014-2015.csv")

# %%
df.State.value_counts()
# Out:
# TX    469
# GA    318
# VA    266
# KY    240
# MO    229
# IL    204
# NC    200
# KS    199
# IA    198
# TN    190
# IN    184
# OH    176
# MN    174
# MI    164
# MS    163
# NE    157
# OK    154
# AR    150
# WI    144
# FL    134
# PA    134
# AL    134
# LA    128
# NY    124
# CO    119
# SD    117
# CA    114
# WV    110
# ND     92
# MT     92
# SC     92
# ID     84
# WA     78
# OR     67
# NM     64
# UT     54
# MD     48
# AK     46
# WY     46
# NJ     42
# NV     32
# ME     32
# AZ     30
# MA     28
# VT     28
# NH     20
# CT     16
# RI     10
# HI      8
# DE      6
# DC      1
# Name: State, dtype: int64

# %%
df[df["State"] == "NC"]
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %%
df[["State", "Year", "Teen births"]][3245:3443]
# Out:
#      State      Year  Teen births
# 3245    NC  1/1/2014         44.2
# 3246    NC  1/1/2015         42.1
# 3247    NC  1/1/2014         53.8
# 3248    NC  1/1/2015         57.5
# 3249    NC  1/1/2014         60.7
# ...    ...       ...          ...
# 3438    NC  1/1/2015         57.3
# 3439    NC  1/1/2014         48.8
# 3440    NC  1/1/2015         46.8
# 3441    NC  1/1/2014         40.2
# 3442    NC  1/1/2015         41.7
#
# [198 rows x 3 columns]

# %%
NCbirths=df[["State", "Year", "Teen births"]][3245:3443]

# %%
print(NCbirths)
# Out:
#      State      Year  Teen births
# 3245    NC  1/1/2014         44.2
# 3246    NC  1/1/2015         42.1
# 3247    NC  1/1/2014         53.8
# 3248    NC  1/1/2015         57.5
# 3249    NC  1/1/2014         60.7
# ...    ...       ...          ...
# 3438    NC  1/1/2015         57.3
# 3439    NC  1/1/2014         48.8
# 3440    NC  1/1/2015         46.8
# 3441    NC  1/1/2014         40.2
# 3442    NC  1/1/2015         41.7
#
# [198 rows x 3 columns]

# %%
df[df["State"] == "GA"]
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 750     GA  South  South Atlantic    Appling County  13001  13001
# 751     GA  South  South Atlantic    Appling County  13001  13001
# 752     GA  South  South Atlantic   Atkinson County  13003  13003
# 753     GA  South  South Atlantic   Atkinson County  13003  13003
# 754     GA  South  South Atlantic      Bacon County  13005  13005
# ...    ...    ...             ...               ...    ...    ...
# 1063    GA  South  South Atlantic     Wilkes County  13317  13317
# 1064    GA  South  South Atlantic  Wilkinson County  13319  13319
# 1065    GA  South  South Atlantic  Wilkinson County  13319  13319
# 1066    GA  South  South Atlantic      Worth County  13321  13321
# 1067    GA  South  South Atlantic      Worth County  13321  13321
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 750     Region 15  1/1/2014          11116.0                0.239  ...
# ...

# %%
df[["State", "Year", "Teen births"]][752:1068]
# Out:
#      State      Year  Teen births
# 752     GA  1/1/2014         91.6
# 753     GA  1/1/2015         90.2
# 754     GA  1/1/2014         91.6
# 755     GA  1/1/2015         93.3
# 756     GA  1/1/2014         41.3
# ...    ...       ...          ...
# 1063    GA  1/1/2015         49.2
# 1064    GA  1/1/2014         61.5
# 1065    GA  1/1/2015         53.7
# 1066    GA  1/1/2014         48.4
# 1067    GA  1/1/2015         49.2
#
# [316 rows x 3 columns]

# %%
GAbirths=df[["State", "Year", "Teen births"]][752:1068]

# %%
print(GAbirths)
# Out:
#      State      Year  Teen births
# 752     GA  1/1/2014         91.6
# 753     GA  1/1/2015         90.2
# 754     GA  1/1/2014         91.6
# 755     GA  1/1/2015         93.3
# 756     GA  1/1/2014         41.3
# ...    ...       ...          ...
# 1063    GA  1/1/2015         49.2
# 1064    GA  1/1/2014         61.5
# 1065    GA  1/1/2015         53.7
# 1066    GA  1/1/2014         48.4
# 1067    GA  1/1/2015         49.2
#
# [316 rows x 3 columns]

# %%
pd.concat([GAbirths,NCbirths],axis=0,ignore_index=True,sort=False)
# Out:
#     State      Year  Teen births
# 0      GA  1/1/2014         91.6
# 1      GA  1/1/2015         90.2
# 2      GA  1/1/2014         91.6
# 3      GA  1/1/2015         93.3
# 4      GA  1/1/2014         41.3
# ..    ...       ...          ...
# 509    NC  1/1/2015         57.3
# 510    NC  1/1/2014         48.8
# 511    NC  1/1/2015         46.8
# 512    NC  1/1/2014         40.2
# 513    NC  1/1/2015         41.7
#
# [514 rows x 3 columns]

# %%
pd.concat([GAbirths,NCbirths],axis=0,ignore_index=True,sort=False)
# Out:
#     State      Year  Teen births
# 0      GA  1/1/2014         91.6
# 1      GA  1/1/2015         90.2
# 2      GA  1/1/2014         91.6
# 3      GA  1/1/2015         93.3
# 4      GA  1/1/2014         41.3
# ..    ...       ...          ...
# 509    NC  1/1/2015         57.3
# 510    NC  1/1/2014         48.8
# 511    NC  1/1/2015         46.8
# 512    NC  1/1/2014         40.2
# 513    NC  1/1/2015         41.7
#
# [514 rows x 3 columns]

# %%
pd.concat([GAbirths,NCbirths],axis=0,ignore_index=True,sort=False)
# Out:
#     State      Year  Teen births
# 0      GA  1/1/2014         91.6
# 1      GA  1/1/2015         90.2
# 2      GA  1/1/2014         91.6
# 3      GA  1/1/2015         93.3
# 4      GA  1/1/2014         41.3
# ..    ...       ...          ...
# 509    NC  1/1/2015         57.3
# 510    NC  1/1/2014         48.8
# 511    NC  1/1/2015         46.8
# 512    NC  1/1/2014         40.2
# 513    NC  1/1/2015         41.7
#
# [514 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Teen births'].plot(kind='hist', bins=20, title='Teen births')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_10['Year'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_10, x='Teen births', y='Year', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_9['State'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_9, x='Teen births', y='State', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Year'].value_counts()
    for x_label, grp in _df_8.groupby('State')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('State')
_ = plt.ylabel('Year')

# %%
from matplotlib import pyplot as plt
_df_7['Teen births'].plot(kind='line', figsize=(8, 4), title='Teen births')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_2.groupby('Year').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_1.groupby('State').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Teen births'].plot(kind='hist', bins=20, title='Teen births')
plt.gca().spines[['top', 'right',]].set_visible(False)
